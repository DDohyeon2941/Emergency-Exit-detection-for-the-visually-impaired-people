# %%
import os, sys
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Dense, Activation, BatchNormalization, \
                                    Flatten, Conv3D, AveragePooling3D, MaxPooling3D, Dropout, \
                                    Concatenate, GlobalMaxPool3D, GlobalAvgPool3D
from tensorflow.keras.models import Sequential, Model, load_model
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# Augment images for each class

# %%
trn_dir = '/content/gdrive/My Drive/IOT_Project/data/singular/Binary/Train/Raw'
trn_aug_dir = '/content/gdrive/My Drive/IOT_Project/data/singular/Binary/Train/Augmented'
trn_cls_0_path = os.path.join(trn_dir, 'Emergency'), os.path.join(trn_aug_dir, 'Emergency')

# %%
temp_gen = ImageDataGenerator(horizontal_flip=True, vertical_flip=True) 
temp_flow_gen = temp_gen.flow_from_directory(trn_cls_0_path[0], shuffle = False, target_size=(224, 224), batch_size=1, class_mode = None, save_to_dir = trn_cls_0_path[1] )
# Out:
# Found 100 images belonging to 1 classes.

# %% [markdown]
# Class 0, Emergency

# %%
added_size=0
for uni_img in temp_flow_gen:
    if added_size > 600:
        break
    if added_size % 25 == 0:
        print(added_size)
    added_size+=1
# Out:
# 0
# 25
# 50
# 75
# 100
# 125
# 150
# 175
# 200
# 225
# 250
# 275
# 300
# 325
# 350
# 375
# 400
# 425
# 450
# 475
# 500
# 525
# 550
# 575
# 600
